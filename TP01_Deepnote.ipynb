# %% [markdown]
# # TP01 \- Deepnote Fernández Agustina

# %% [markdown]
# Mi nombre es Agustina, tengo 34 años\. Soy técnica en laboratorio y en este momento estoy trabajando como extraccionista en un centro de hematología\.

# %% [markdown]
# Tengo la expectativa con esta materia de adquirir los conocimientos para introducirme en el mundo de la IA\.

# %%
print("Mi primer notebook en Deepnote")
# Out:
# Mi primer notebook en Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=62bd93cc-1367-4433-a26d-e53b8483c5a0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
