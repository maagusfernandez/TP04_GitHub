# %% [markdown]
# # TP02 – Introducción a Python

# %% [markdown]
# Fernández María Agustina

# %% [markdown]
# ### Ejercicio 1 – Variables y operaciones

# %%
nombre = "Agustina Fernández"
edad = 34
ciudad = "Buenos Aires"
print ("Hola, mi nombre es", nombre,",tengo", edad, "años y vivo en", ciudad)
# Out:
# Hola, mi nombre es Agustina Fernández ,tengo 34 años y vivo en Buenos Aires

# %%
a= 2
b= 6
resultado = a + b
print (resultado)
# Out:
# 8

# %%
a= 6
b= 2
resultado = a - b
print (resultado)
# Out:
# -4

# %%
a= 2
b= 6
resultado = a * b
print (resultado)
# Out:
# 12

# %%
a= 6
b= 2
resultado = a / b
print (resultado)
# Out:
# 3.0

# %% [markdown]
# ### Ejercicio 2 – Condicionales

# %%
edad = int(input("ingrese su edad:"))
if edad >=18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# ### Ejercicio 3 – Listas y bucles

# %%
numeros = [5, 9, 12, 25, 41]
for i in numeros:
    print (i)
# Out:
# 5
# 9
# 12
# 25
# 41

# %%
numeros = [5, 9, 12, 25, 41]
suma = 0
for i in numeros:
    suma = suma + i
print (suma)
# Out:
# 92

# %%
numeros = [5, 9, 12, 25, 41]
suma = 0
promedio = 0
for i in numeros:
    suma = (suma + i)
promedio = suma/5
print (promedio)
# Out:
# 18.4

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=62bd93cc-1367-4433-a26d-e53b8483c5a0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
